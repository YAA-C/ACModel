# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
assert(len(tf.config.list_physical_devices('GPU')) > 0), "You are not using GPU"
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (84212, 96, 27)

# %%
Y.shape
# Out:
# (84212,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (75790, 96, 27)
# (75790,)
# (8422, 96, 27)
# (8422,)

# %%
model = Sequential()
model.add(LSTM(32, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(1/10))
model.add(LSTM(32))
model.add(Dropout(1/10))
model.add(Dense(X.shape[1], activation='relu'))
model.add(Dropout(1/10))
model.add(Dense(X.shape[1] / 2, activation='relu'))
model.add(Dropout(1/10))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# 948/948 [==============================] - 30s 29ms/step - loss: 0.3238 - accuracy: 0.8933 - val_loss: 0.3110 - val_accuracy: 0.8966
# Epoch 2/20
# 948/948 [==============================] - 28s 30ms/step - loss: 0.3083 - accuracy: 0.8969 - val_loss: 0.3078 - val_accuracy: 0.8966
# Epoch 3/20
# 948/948 [==============================] - 24s 25ms/step - loss: 0.3054 - accuracy: 0.8971 - val_loss: 0.3078 - val_accuracy: 0.8956
# Epoch 4/20
# 948/948 [==============================] - 29s 30ms/step - loss: 0.3048 - accuracy: 0.8970 - val_loss: 0.3050 - val_accuracy: 0.8956
# Epoch 5/20
# 948/948 [==============================] - 28s 29ms/step - loss: 0.3043 - accuracy: 0.8971 - val_loss: 0.3064 - val_accuracy: 0.8958
# Epoch 6/20
# 948/948 [==============================] - 26s 27ms/step - loss: 0.3045 - accuracy: 0.8970 - val_loss: 0.3044 - val_accuracy: 0.8958
# Epoch 7/20
# 948/948 [==============================] - 31s 32ms/step - loss: 0.3040 - accuracy: 0.8973 - val_loss: 0.3042 - val_accuracy: 0.8958
# Epoch 8/20
# 948/948 [==============================] - 34s 36ms/step - loss: 0.3037 - accuracy: 0.8971 - val_loss: 0.3060 - val_accuracy: 0.8958
# Epoch 9/20
# 948/948 [==============================] - 31s 33ms/step - loss: 0.3026 - accuracy: 0.8974 - val_loss: 0.3074 - val_accuracy: 0.8958
# Epoch 10/20
# 948/948 [==============================] - 29s 31ms/step - loss: 0.3020 - accuracy: 0.8975 - val_loss: 0.3066 - val_accuracy: 0.8956
# Epoch 11/20
# 948/948 [==============================] - 30s 31ms/step - loss: 0.3017 - accuracy: 0.8973 - val_loss: 0.3034 - val_accuracy: 0.8958
# Epoch 12/20
# 948/948 [==============================] - 28s 29ms/step - loss: 0.3017 - accuracy: 0.8973 - val_loss: 0.3092 - val_accuracy: 0.8961
# Epoch 13/20
# 948/948 [==============================] - 30s 31ms/step - loss: 0.3013 - accuracy: 0.8972 - val_loss: 0.3071 - val_accuracy: 0.8966
# Epoch 14/20
# 948/948 [==============================] - 28s 29ms/step - loss: 0.3009 - accuracy: 0.8970 - val_loss: 0.3036 - val_accuracy: 0.8956
# Epoch 15/20
# 948/948 [==============================] - 29s 30ms/step - loss: 0.3018 - accuracy: 0.8974 - val_loss: 0.3034 - val_accuracy: 0.8958
# Epoch 16/20
# 948/948 [==============================] - 27s 29ms/step - loss: 0.3009 - accuracy: 0.8973 - val_loss: 0.3041 - val_accuracy: 0.8966
# Epoch 17/20
# 948/948 [==============================] - 24s 26ms/step - loss: 0.3010 - accuracy: 0.8970 - val_loss: 0.3057 - val_accuracy: 0.8956
# Epoch 18/20
# 948/948 [==============================] - 17s 18ms/step - loss: 0.3023 - accuracy: 0.8971 - val_loss: 0.3044 - val_accuracy: 0.8958
# Epoch 19/20
# 948/948 [==============================] - 17s 18ms/step - loss: 0.3022 - accuracy: 0.8975 - val_loss: 0.3074 - val_accuracy: 0.8956
# Epoch 20/20
# 948/948 [==============================] - 22s 23ms/step - loss: 0.3011 - accuracy: 0.8975 - val_loss: 0.3043 - val_accuracy: 0.8966

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 264/264 [==============================] - 2s 7ms/step - loss: 0.3010 - accuracy: 0.8982
# Test loss: 0.3010396957397461, Test accuracy: 0.898242712020874

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 264/264 [==============================] - 2s 6ms/step
# Accuracy: 0.8982426976965091

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1327
# True Negatives: 6238
# False Positives: 125
# False Negatives: 732

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7559099971518086
# Precision: 0.9139118457300276
# Recall: 0.644487615347256

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

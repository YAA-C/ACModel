# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (84212, 96, 27)

# %%
Y.shape
# Out:
# (84212,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (75790, 96, 27)
# (75790,)
# (8422, 96, 27)
# (8422,)

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(1/10))
model.add(LSTM(64))
model.add(Dropout(1/10))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 948/948 [==============================] - 89s 89ms/step - loss: 0.3131 - accuracy: 0.8955 - val_loss: 0.3099 - val_accuracy: 0.8958
# Epoch 2/20
# 948/948 [==============================] - 134s 142ms/step - loss: 0.3046 - accuracy: 0.8971 - val_loss: 0.3076 - val_accuracy: 0.8958
# Epoch 3/20
# 948/948 [==============================] - 137s 145ms/step - loss: 0.3034 - accuracy: 0.8974 - val_loss: 0.3051 - val_accuracy: 0.8956
# Epoch 4/20
# 948/948 [==============================] - 137s 144ms/step - loss: 0.3028 - accuracy: 0.8973 - val_loss: 0.3065 - val_accuracy: 0.8956
# Epoch 5/20
# 948/948 [==============================] - 125s 132ms/step - loss: 0.3021 - accuracy: 0.8971 - val_loss: 0.3061 - val_accuracy: 0.8956
# Epoch 6/20
# 948/948 [==============================] - 125s 132ms/step - loss: 0.3009 - accuracy: 0.8975 - val_loss: 0.3039 - val_accuracy: 0.8956
# Epoch 7/20
# 948/948 [==============================] - 127s 134ms/step - loss: 0.3004 - accuracy: 0.8973 - val_loss: 0.3026 - val_accuracy: 0.8958
# Epoch 8/20
# 948/948 [==============================] - 127s 134ms/step - loss: 0.3003 - accuracy: 0.8972 - val_loss: 0.3030 - val_accuracy: 0.8958
# Epoch 9/20
# 948/948 [==============================] - 133s 140ms/step - loss: 0.3002 - accuracy: 0.8972 - val_loss: 0.3038 - val_accuracy: 0.8958
# Epoch 10/20
# 948/948 [==============================] - 133s 140ms/step - loss: 0.2997 - accuracy: 0.8978 - val_loss: 0.3037 - val_accuracy: 0.8956
# Epoch 11/20
# 948/948 [==============================] - 226s 239ms/step - loss: 0.2995 - accuracy: 0.8974 - val_loss: 0.3023 - val_accuracy: 0.8958
# Epoch 12/20
# 948/948 [==============================] - 209s 220ms/step - loss: 0.2997 - accuracy: 0.8973 - val_loss: 0.3027 - val_accuracy: 0.8958
# Epoch 13/20
# 948/948 [==============================] - 209s 221ms/step - loss: 0.2987 - accuracy: 0.8972 - val_loss: 0.3047 - val_accuracy: 0.8956
# Epoch 14/20
# 948/948 [==============================] - 206s 217ms/step - loss: 0.2990 - accuracy: 0.8975 - val_loss: 0.3027 - val_accuracy: 0.8958
# Epoch 15/20
# 948/948 [==============================] - 217s 229ms/step - loss: 0.2987 - accuracy: 0.8973 - val_loss: 0.3039 - val_accuracy: 0.8961
# Epoch 16/20
# 948/948 [==============================] - 133s 141ms/step - loss: 0.2990 - accuracy: 0.8974 - val_loss: 0.3019 - val_accuracy: 0.8962
# Epoch 17/20
# 948/948 [==============================] - 118s 124ms/step - loss: 0.2986 - accuracy: 0.8977 - val_loss: 0.3027 - val_accuracy: 0.8961
# Epoch 18/20
# 948/948 [==============================] - 114s 120ms/step - loss: 0.2978 - accuracy: 0.8975 - val_loss: 0.3025 - val_accuracy: 0.8962
# Epoch 19/20
# 948/948 [==============================] - 124s 131ms/step - loss: 0.2979 - accuracy: 0.8976 - val_loss: 0.3028 - val_accuracy: 0.8962
# Epoch 20/20
# 948/948 [==============================] - 138s 146ms/step - loss: 0.2988 - accuracy: 0.8975 - val_loss: 0.3040 - val_accuracy: 0.8961

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 264/264 [==============================] - 9s 34ms/step - loss: 0.3012 - accuracy: 0.8967
# Test loss: 0.30119794607162476, Test accuracy: 0.8966991305351257

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 264/264 [==============================] - 9s 31ms/step
# Accuracy: 0.8966991213488482

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1292
# True Negatives: 6260
# False Positives: 103
# False Negatives: 767

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7481181239143022
# Precision: 0.9261648745519713
# Recall: 0.6274890723652259

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (84212, 96, 27)

# %%
Y.shape
# Out:
# (84212,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (75790, 96, 27)
# (75790,)
# (8422, 96, 27)
# (8422,)

# %%
model = Sequential()
model.add(LSTM(32, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(1/10))
model.add(LSTM(32))
model.add(Dropout(1/10))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 948/948 [==============================] - 87s 85ms/step - loss: 0.3218 - accuracy: 0.8930 - val_loss: 0.3165 - val_accuracy: 0.8956
# Epoch 2/20
# 948/948 [==============================] - 78s 83ms/step - loss: 0.3081 - accuracy: 0.8971 - val_loss: 0.3116 - val_accuracy: 0.8961
# Epoch 3/20
# 948/948 [==============================] - 80s 84ms/step - loss: 0.3052 - accuracy: 0.8972 - val_loss: 0.3063 - val_accuracy: 0.8956
# Epoch 4/20
# 948/948 [==============================] - 80s 84ms/step - loss: 0.3038 - accuracy: 0.8974 - val_loss: 0.3052 - val_accuracy: 0.8958
# Epoch 5/20
# 948/948 [==============================] - 71s 74ms/step - loss: 0.3029 - accuracy: 0.8971 - val_loss: 0.3056 - val_accuracy: 0.8966
# Epoch 6/20
# 948/948 [==============================] - 88s 93ms/step - loss: 0.3023 - accuracy: 0.8974 - val_loss: 0.3054 - val_accuracy: 0.8958
# Epoch 7/20
# 948/948 [==============================] - 45s 47ms/step - loss: 0.3024 - accuracy: 0.8973 - val_loss: 0.3077 - val_accuracy: 0.8956
# Epoch 8/20
# 948/948 [==============================] - 34s 36ms/step - loss: 0.3026 - accuracy: 0.8972 - val_loss: 0.3054 - val_accuracy: 0.8956
# Epoch 9/20
# 948/948 [==============================] - 34s 36ms/step - loss: 0.3015 - accuracy: 0.8974 - val_loss: 0.3055 - val_accuracy: 0.8958
# Epoch 10/20
# 948/948 [==============================] - 34s 35ms/step - loss: 0.3017 - accuracy: 0.8973 - val_loss: 0.3056 - val_accuracy: 0.8958
# Epoch 11/20
# 948/948 [==============================] - 34s 36ms/step - loss: 0.3010 - accuracy: 0.8974 - val_loss: 0.3054 - val_accuracy: 0.8956
# Epoch 12/20
# 948/948 [==============================] - 34s 35ms/step - loss: 0.3005 - accuracy: 0.8973 - val_loss: 0.3038 - val_accuracy: 0.8958
# Epoch 13/20
# 948/948 [==============================] - 80s 84ms/step - loss: 0.3005 - accuracy: 0.8972 - val_loss: 0.3043 - val_accuracy: 0.8948
# Epoch 14/20
# 948/948 [==============================] - 104s 110ms/step - loss: 0.3001 - accuracy: 0.8972 - val_loss: 0.3033 - val_accuracy: 0.8958
# Epoch 15/20
# 948/948 [==============================] - 125s 132ms/step - loss: 0.3006 - accuracy: 0.8976 - val_loss: 0.3045 - val_accuracy: 0.8966
# Epoch 16/20
# 948/948 [==============================] - 121s 128ms/step - loss: 0.2995 - accuracy: 0.8974 - val_loss: 0.3054 - val_accuracy: 0.8966
# Epoch 17/20
# 948/948 [==============================] - 108s 114ms/step - loss: 0.3004 - accuracy: 0.8973 - val_loss: 0.3035 - val_accuracy: 0.8956
# Epoch 18/20
# 948/948 [==============================] - 82s 86ms/step - loss: 0.3001 - accuracy: 0.8971 - val_loss: 0.3051 - val_accuracy: 0.8958
# Epoch 19/20
# 948/948 [==============================] - 81s 85ms/step - loss: 0.2996 - accuracy: 0.8975 - val_loss: 0.3040 - val_accuracy: 0.8966
# Epoch 20/20
# 948/948 [==============================] - 80s 85ms/step - loss: 0.2997 - accuracy: 0.8972 - val_loss: 0.3031 - val_accuracy: 0.8958

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 264/264 [==============================] - 7s 25ms/step - loss: 0.3004 - accuracy: 0.8973
# Test loss: 0.3003650903701782, Test accuracy: 0.8972927927970886

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 264/264 [==============================] - 8s 27ms/step
# Accuracy: 0.897292804559487

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1306
# True Negatives: 6251
# False Positives: 112
# False Negatives: 753

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7512223180903076
# Precision: 0.921015514809591
# Recall: 0.6342884895580378

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

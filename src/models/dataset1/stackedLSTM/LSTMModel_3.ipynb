# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (70646, 128, 27)

# %%
Y.shape
# Out:
# (70646,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (63581, 128, 27)
# (63581,)
# (7065, 128, 27)
# (7065,)

# %%
model = Sequential()
model.add(LSTM(128 , input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(1/10))
model.add(LSTM(128))
model.add(Dropout(1/10))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 795/795 [==============================] - 311s 384ms/step - loss: 0.3354 - accuracy: 0.8803 - val_loss: 0.3227 - val_accuracy: 0.8851
# Epoch 2/20
# 795/795 [==============================] - 298s 375ms/step - loss: 0.3230 - accuracy: 0.8858 - val_loss: 0.3184 - val_accuracy: 0.8861
# Epoch 3/20
# 795/795 [==============================] - 306s 385ms/step - loss: 0.3206 - accuracy: 0.8861 - val_loss: 0.3277 - val_accuracy: 0.8862
# Epoch 4/20
# 795/795 [==============================] - 321s 404ms/step - loss: 0.3179 - accuracy: 0.8867 - val_loss: 0.3135 - val_accuracy: 0.8883
# Epoch 5/20
# 795/795 [==============================] - 312s 392ms/step - loss: 0.3169 - accuracy: 0.8861 - val_loss: 0.3170 - val_accuracy: 0.8865
# Epoch 6/20
# 795/795 [==============================] - 318s 400ms/step - loss: 0.3155 - accuracy: 0.8865 - val_loss: 0.3143 - val_accuracy: 0.8868
# Epoch 7/20
# 795/795 [==============================] - 310s 389ms/step - loss: 0.3149 - accuracy: 0.8867 - val_loss: 0.3122 - val_accuracy: 0.8871
# Epoch 8/20
# 795/795 [==============================] - 309s 389ms/step - loss: 0.3151 - accuracy: 0.8866 - val_loss: 0.3117 - val_accuracy: 0.8878
# Epoch 9/20
# 795/795 [==============================] - 309s 388ms/step - loss: 0.3136 - accuracy: 0.8870 - val_loss: 0.3116 - val_accuracy: 0.8871
# Epoch 10/20
# 795/795 [==============================] - 343s 432ms/step - loss: 0.3138 - accuracy: 0.8871 - val_loss: 0.3113 - val_accuracy: 0.8876
# Epoch 11/20
# 795/795 [==============================] - 284s 357ms/step - loss: 0.3137 - accuracy: 0.8871 - val_loss: 0.3101 - val_accuracy: 0.8876
# Epoch 12/20
# 795/795 [==============================] - 366s 461ms/step - loss: 0.3124 - accuracy: 0.8871 - val_loss: 0.3136 - val_accuracy: 0.8883
# Epoch 13/20
# 795/795 [==============================] - 397s 500ms/step - loss: 0.3125 - accuracy: 0.8872 - val_loss: 0.3105 - val_accuracy: 0.8867
# Epoch 14/20
# 795/795 [==============================] - 357s 449ms/step - loss: 0.3126 - accuracy: 0.8872 - val_loss: 0.3099 - val_accuracy: 0.8878
# Epoch 15/20
# 795/795 [==============================] - 387s 487ms/step - loss: 0.3122 - accuracy: 0.8869 - val_loss: 0.3141 - val_accuracy: 0.8871
# Epoch 16/20
# 795/795 [==============================] - 365s 459ms/step - loss: 0.3129 - accuracy: 0.8872 - val_loss: 0.3111 - val_accuracy: 0.8867
# Epoch 17/20
# 795/795 [==============================] - 360s 453ms/step - loss: 0.3113 - accuracy: 0.8876 - val_loss: 0.3097 - val_accuracy: 0.8871
# Epoch 18/20
# 795/795 [==============================] - 358s 450ms/step - loss: 0.3123 - accuracy: 0.8877 - val_loss: 0.3115 - val_accuracy: 0.8876
# Epoch 19/20
# 795/795 [==============================] - 384s 483ms/step - loss: 0.3113 - accuracy: 0.8875 - val_loss: 0.3148 - val_accuracy: 0.8876
# Epoch 20/20
# 795/795 [==============================] - 365s 459ms/step - loss: 0.3104 - accuracy: 0.8877 - val_loss: 0.3097 - val_accuracy: 0.8878

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 221/221 [==============================] - 20s 89ms/step - loss: 0.3108 - accuracy: 0.8886
# Test loss: 0.31080374121665955, Test accuracy: 0.8886058330535889

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 221/221 [==============================] - 22s 92ms/step
# Accuracy: 0.8886058032554848

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1205
# True Negatives: 5073
# False Positives: 69
# False Negatives: 718

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7538317172349076
# Precision: 0.945839874411303
# Recall: 0.6266250650026001

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

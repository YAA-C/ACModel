# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
assert(len(tf.config.list_physical_devices('GPU')) > 0), "You are not using GPU"
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (109771, 1, 27)

# %%
Y.shape
# Out:
# (109771,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (98793, 1, 27)
# (98793,)
# (10978, 1, 27)
# (10978,)

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(X.shape[1], X.shape[2])))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# 1235/1235 [==============================] - 59s 44ms/step - loss: 0.5459 - accuracy: 0.7671 - val_loss: 0.5407 - val_accuracy: 0.7683
# Epoch 2/20
# 1235/1235 [==============================] - 50s 41ms/step - loss: 0.5434 - accuracy: 0.7680 - val_loss: 0.5422 - val_accuracy: 0.7683
# Epoch 3/20
# 1235/1235 [==============================] - 50s 40ms/step - loss: 0.5423 - accuracy: 0.7680 - val_loss: 0.5406 - val_accuracy: 0.7683
# Epoch 4/20
# 1235/1235 [==============================] - 53s 43ms/step - loss: 0.5428 - accuracy: 0.7680 - val_loss: 0.5407 - val_accuracy: 0.7683
# Epoch 5/20
# 1235/1235 [==============================] - 47s 38ms/step - loss: 0.5414 - accuracy: 0.7680 - val_loss: 0.5414 - val_accuracy: 0.7683
# Epoch 6/20
# 1235/1235 [==============================] - 52s 42ms/step - loss: 0.5405 - accuracy: 0.7680 - val_loss: 0.5402 - val_accuracy: 0.7683
# Epoch 7/20
# 1235/1235 [==============================] - 53s 42ms/step - loss: 0.5406 - accuracy: 0.7680 - val_loss: 0.5388 - val_accuracy: 0.7683
# Epoch 8/20
# 1235/1235 [==============================] - 51s 41ms/step - loss: 0.5403 - accuracy: 0.7680 - val_loss: 0.5393 - val_accuracy: 0.7683
# Epoch 9/20
# 1235/1235 [==============================] - 47s 38ms/step - loss: 0.5390 - accuracy: 0.7680 - val_loss: 0.5378 - val_accuracy: 0.7683
# Epoch 10/20
# 1235/1235 [==============================] - 49s 40ms/step - loss: 0.5376 - accuracy: 0.7680 - val_loss: 0.5390 - val_accuracy: 0.7683
# Epoch 11/20
# 1235/1235 [==============================] - 47s 38ms/step - loss: 0.5386 - accuracy: 0.7680 - val_loss: 0.5367 - val_accuracy: 0.7683
# Epoch 12/20
# 1235/1235 [==============================] - 176s 143ms/step - loss: 0.5389 - accuracy: 0.7680 - val_loss: 0.5265 - val_accuracy: 0.7683
# Epoch 13/20
# 1235/1235 [==============================] - 183s 148ms/step - loss: 0.5381 - accuracy: 0.7680 - val_loss: 0.5375 - val_accuracy: 0.7683
# Epoch 14/20
# 1235/1235 [==============================] - 199s 161ms/step - loss: 0.5358 - accuracy: 0.7680 - val_loss: 0.5377 - val_accuracy: 0.7683
# Epoch 15/20
# 1235/1235 [==============================] - 213s 172ms/step - loss: 0.5366 - accuracy: 0.7680 - val_loss: 0.5232 - val_accuracy: 0.7683
# Epoch 16/20
# 1235/1235 [==============================] - 190s 154ms/step - loss: 0.5379 - accuracy: 0.7680 - val_loss: 0.5389 - val_accuracy: 0.7683
# Epoch 17/20
# 1235/1235 [==============================] - 207s 167ms/step - loss: 0.5385 - accuracy: 0.7680 - val_loss: 0.5369 - val_accuracy: 0.7683
# Epoch 18/20
# 1235/1235 [==============================] - 188s 153ms/step - loss: 0.5369 - accuracy: 0.7680 - val_loss: 0.5377 - val_accuracy: 0.7683
# Epoch 19/20
# 1235/1235 [==============================] - 11s 9ms/step - loss: 0.5351 - accuracy: 0.7680 - val_loss: 0.5319 - val_accuracy: 0.7683
# Epoch 20/20
# 1235/1235 [==============================] - 12s 9ms/step - loss: 0.5351 - accuracy: 0.7680 - val_loss: 0.5379 - val_accuracy: 0.7683

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 344/344 [==============================] - 2s 5ms/step - loss: 0.5405 - accuracy: 0.7668
# Test loss: 0.5404533743858337, Test accuracy: 0.7668063640594482

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 344/344 [==============================] - 2s 3ms/step
# Accuracy: 0.7668063399526326

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 0
# True Negatives: 8418
# False Positives: 0
# False Negatives: 2560

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.0
# Precision: 0.0
# Recall: 0.0
# C:\Users\dhing\miniconda3\envs\dl\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

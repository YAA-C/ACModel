# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
assert(len(tf.config.list_physical_devices('GPU')) > 0), "You are not using GPU"
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (84212, 96, 27)

# %%
Y.shape
# Out:
# (84212,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (75790, 96, 27)
# (75790,)
# (8422, 96, 27)
# (8422,)

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(1/10))
model.add(LSTM(64))
model.add(Dropout(1/10))
model.add(Dense(X.shape[1], activation='relu'))
model.add(Dropout(1/10))
model.add(Dense(X.shape[1] / 2, activation='relu'))
model.add(Dropout(1/10))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# 948/948 [==============================] - 35s 31ms/step - loss: 0.3205 - accuracy: 0.8936 - val_loss: 0.3089 - val_accuracy: 0.8958
# Epoch 2/20
# 948/948 [==============================] - 19s 21ms/step - loss: 0.3079 - accuracy: 0.8969 - val_loss: 0.3071 - val_accuracy: 0.8956
# Epoch 3/20
# 948/948 [==============================] - 14s 14ms/step - loss: 0.3060 - accuracy: 0.8971 - val_loss: 0.3063 - val_accuracy: 0.8958
# Epoch 4/20
# 948/948 [==============================] - 16s 16ms/step - loss: 0.3044 - accuracy: 0.8971 - val_loss: 0.3063 - val_accuracy: 0.8956
# Epoch 5/20
# 948/948 [==============================] - 15s 16ms/step - loss: 0.3037 - accuracy: 0.8973 - val_loss: 0.3063 - val_accuracy: 0.8958
# Epoch 6/20
# 948/948 [==============================] - 15s 15ms/step - loss: 0.3032 - accuracy: 0.8973 - val_loss: 0.3043 - val_accuracy: 0.8966
# Epoch 7/20
# 948/948 [==============================] - 20s 22ms/step - loss: 0.3032 - accuracy: 0.8972 - val_loss: 0.3056 - val_accuracy: 0.8958
# Epoch 8/20
# 948/948 [==============================] - 22s 23ms/step - loss: 0.3039 - accuracy: 0.8973 - val_loss: 0.3043 - val_accuracy: 0.8958
# Epoch 9/20
# 948/948 [==============================] - 21s 22ms/step - loss: 0.3028 - accuracy: 0.8974 - val_loss: 0.3049 - val_accuracy: 0.8956
# Epoch 10/20
# 948/948 [==============================] - 27s 29ms/step - loss: 0.3018 - accuracy: 0.8975 - val_loss: 0.3042 - val_accuracy: 0.8956
# Epoch 11/20
# 948/948 [==============================] - 23s 24ms/step - loss: 0.3013 - accuracy: 0.8971 - val_loss: 0.3054 - val_accuracy: 0.8960
# Epoch 12/20
# 948/948 [==============================] - 23s 24ms/step - loss: 0.3003 - accuracy: 0.8973 - val_loss: 0.3084 - val_accuracy: 0.8960
# Epoch 13/20
# 948/948 [==============================] - 23s 24ms/step - loss: 0.3009 - accuracy: 0.8973 - val_loss: 0.3042 - val_accuracy: 0.8962
# Epoch 14/20
# 948/948 [==============================] - 21s 23ms/step - loss: 0.3006 - accuracy: 0.8974 - val_loss: 0.3080 - val_accuracy: 0.8957
# Epoch 15/20
# 948/948 [==============================] - 21s 23ms/step - loss: 0.3000 - accuracy: 0.8978 - val_loss: 0.3052 - val_accuracy: 0.8958
# Epoch 16/20
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3001 - accuracy: 0.8974 - val_loss: 0.3093 - val_accuracy: 0.8961
# Epoch 17/20
# 948/948 [==============================] - 32s 34ms/step - loss: 0.3009 - accuracy: 0.8974 - val_loss: 0.3070 - val_accuracy: 0.8960
# Epoch 18/20
# 948/948 [==============================] - 29s 31ms/step - loss: 0.2997 - accuracy: 0.8975 - val_loss: 0.3023 - val_accuracy: 0.8960
# Epoch 19/20
# 948/948 [==============================] - 32s 34ms/step - loss: 0.2994 - accuracy: 0.8976 - val_loss: 0.3038 - val_accuracy: 0.8961
# Epoch 20/20
# 948/948 [==============================] - 31s 32ms/step - loss: 0.2989 - accuracy: 0.8982 - val_loss: 0.3020 - val_accuracy: 0.8971

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 264/264 [==============================] - 2s 7ms/step - loss: 0.2977 - accuracy: 0.8992
# Test loss: 0.29773634672164917, Test accuracy: 0.8991925716400146

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 264/264 [==============================] - 2s 6ms/step
# Accuracy: 0.8991925908335312

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1338
# True Negatives: 6235
# False Positives: 128
# False Negatives: 721

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7591489361702127
# Precision: 0.91268758526603
# Recall: 0.6498300145701797

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

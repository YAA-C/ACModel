# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
assert(len(tf.config.list_physical_devices('GPU')) > 0), "You are not using GPU"
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (84212, 96, 27)

# %%
Y.shape
# Out:
# (84212,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (75790, 96, 27)
# (75790,)
# (8422, 96, 27)
# (8422,)

# %%
model = Sequential()
model.add(LSTM(128 , input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(1/10))
model.add(LSTM(128))
model.add(Dropout(1/10))
model.add(Dense(X.shape[1], activation='relu'))
model.add(Dropout(1/10))
model.add(Dense(X.shape[1] / 2, activation='relu'))
model.add(Dropout(1/10))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# 948/948 [==============================] - 58s 43ms/step - loss: 0.3180 - accuracy: 0.8951 - val_loss: 0.3057 - val_accuracy: 0.8966
# Epoch 2/20
# 948/948 [==============================] - 40s 43ms/step - loss: 0.3085 - accuracy: 0.8969 - val_loss: 0.3043 - val_accuracy: 0.8958
# Epoch 3/20
# 948/948 [==============================] - 41s 44ms/step - loss: 0.3062 - accuracy: 0.8972 - val_loss: 0.3082 - val_accuracy: 0.8958
# Epoch 4/20
# 948/948 [==============================] - 43s 46ms/step - loss: 0.3050 - accuracy: 0.8971 - val_loss: 0.3053 - val_accuracy: 0.8958
# Epoch 5/20
# 948/948 [==============================] - 42s 44ms/step - loss: 0.3043 - accuracy: 0.8974 - val_loss: 0.3080 - val_accuracy: 0.8958
# Epoch 6/20
# 948/948 [==============================] - 42s 44ms/step - loss: 0.3033 - accuracy: 0.8968 - val_loss: 0.3120 - val_accuracy: 0.8958
# Epoch 7/20
# 948/948 [==============================] - 39s 42ms/step - loss: 0.3030 - accuracy: 0.8978 - val_loss: 0.3058 - val_accuracy: 0.8958
# Epoch 8/20
# 948/948 [==============================] - 39s 42ms/step - loss: 0.3021 - accuracy: 0.8973 - val_loss: 0.3049 - val_accuracy: 0.8958
# Epoch 9/20
# 948/948 [==============================] - 42s 44ms/step - loss: 0.3016 - accuracy: 0.8975 - val_loss: 0.3040 - val_accuracy: 0.8961
# Epoch 10/20
# 948/948 [==============================] - 43s 46ms/step - loss: 0.3021 - accuracy: 0.8974 - val_loss: 0.3037 - val_accuracy: 0.8956
# Epoch 11/20
# 948/948 [==============================] - 42s 44ms/step - loss: 0.3022 - accuracy: 0.8969 - val_loss: 0.3029 - val_accuracy: 0.8956
# Epoch 12/20
# 948/948 [==============================] - 41s 43ms/step - loss: 0.3008 - accuracy: 0.8974 - val_loss: 0.3038 - val_accuracy: 0.8958
# Epoch 13/20
# 948/948 [==============================] - 39s 41ms/step - loss: 0.3013 - accuracy: 0.8972 - val_loss: 0.3027 - val_accuracy: 0.8958
# Epoch 14/20
# 948/948 [==============================] - 40s 43ms/step - loss: 0.3017 - accuracy: 0.8972 - val_loss: 0.3029 - val_accuracy: 0.8961
# Epoch 15/20
# 948/948 [==============================] - 41s 43ms/step - loss: 0.3000 - accuracy: 0.8971 - val_loss: 0.3036 - val_accuracy: 0.8966
# Epoch 16/20
# 948/948 [==============================] - 42s 45ms/step - loss: 0.3006 - accuracy: 0.8978 - val_loss: 0.3033 - val_accuracy: 0.8971
# Epoch 17/20
# 948/948 [==============================] - 42s 44ms/step - loss: 0.3023 - accuracy: 0.8971 - val_loss: 0.3056 - val_accuracy: 0.8958
# Epoch 18/20
# 948/948 [==============================] - 41s 43ms/step - loss: 0.3006 - accuracy: 0.8973 - val_loss: 0.3074 - val_accuracy: 0.8961
# Epoch 19/20
# 948/948 [==============================] - 39s 41ms/step - loss: 0.2994 - accuracy: 0.8976 - val_loss: 0.3030 - val_accuracy: 0.8970
# Epoch 20/20
# 948/948 [==============================] - 41s 43ms/step - loss: 0.2998 - accuracy: 0.8968 - val_loss: 0.3137 - val_accuracy: 0.8934

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 264/264 [==============================] - 5s 18ms/step - loss: 0.3101 - accuracy: 0.8972
# Test loss: 0.3100976049900055, Test accuracy: 0.897174060344696

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 264/264 [==============================] - 5s 16ms/step
# Accuracy: 0.8971740679173593

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1375
# True Negatives: 6181
# False Positives: 182
# False Negatives: 684

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7605088495575221
# Precision: 0.8831085420680796
# Recall: 0.6677999028654686

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

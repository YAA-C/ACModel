# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (84212, 96, 27)

# %%
Y.shape
# Out:
# (84212,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (75790, 96, 27)
# (75790,)
# (8422, 96, 27)
# (8422,)

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(X.shape[1], X.shape[2])))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 948/948 [==============================] - 107s 109ms/step - loss: 0.3120 - accuracy: 0.8950 - val_loss: 0.3069 - val_accuracy: 0.8958
# Epoch 2/20
# 948/948 [==============================] - 112s 118ms/step - loss: 0.3038 - accuracy: 0.8971 - val_loss: 0.3049 - val_accuracy: 0.8958
# Epoch 3/20
# 948/948 [==============================] - 104s 110ms/step - loss: 0.3022 - accuracy: 0.8974 - val_loss: 0.3055 - val_accuracy: 0.8958
# Epoch 4/20
# 948/948 [==============================] - 103s 109ms/step - loss: 0.3015 - accuracy: 0.8972 - val_loss: 0.3040 - val_accuracy: 0.8966
# Epoch 5/20
# 948/948 [==============================] - 109s 115ms/step - loss: 0.3011 - accuracy: 0.8976 - val_loss: 0.3041 - val_accuracy: 0.8954
# Epoch 6/20
# 948/948 [==============================] - 108s 114ms/step - loss: 0.3006 - accuracy: 0.8977 - val_loss: 0.3040 - val_accuracy: 0.8958
# Epoch 7/20
# 948/948 [==============================] - 116s 123ms/step - loss: 0.3001 - accuracy: 0.8972 - val_loss: 0.3042 - val_accuracy: 0.8956
# Epoch 8/20
# 948/948 [==============================] - 113s 119ms/step - loss: 0.2995 - accuracy: 0.8970 - val_loss: 0.3043 - val_accuracy: 0.8957
# Epoch 9/20
# 948/948 [==============================] - 135s 143ms/step - loss: 0.2993 - accuracy: 0.8975 - val_loss: 0.3045 - val_accuracy: 0.8956
# Epoch 10/20
# 948/948 [==============================] - 133s 140ms/step - loss: 0.2996 - accuracy: 0.8972 - val_loss: 0.3035 - val_accuracy: 0.8956
# Epoch 11/20
# 948/948 [==============================] - 138s 146ms/step - loss: 0.2993 - accuracy: 0.8973 - val_loss: 0.3029 - val_accuracy: 0.8964
# Epoch 12/20
# 948/948 [==============================] - 139s 147ms/step - loss: 0.2991 - accuracy: 0.8970 - val_loss: 0.3035 - val_accuracy: 0.8962
# Epoch 13/20
# 948/948 [==============================] - 121s 128ms/step - loss: 0.2988 - accuracy: 0.8971 - val_loss: 0.3029 - val_accuracy: 0.8966
# Epoch 14/20
# 948/948 [==============================] - 87s 91ms/step - loss: 0.2985 - accuracy: 0.8972 - val_loss: 0.3029 - val_accuracy: 0.8958
# Epoch 15/20
# 948/948 [==============================] - 49s 52ms/step - loss: 0.2984 - accuracy: 0.8973 - val_loss: 0.3026 - val_accuracy: 0.8957
# Epoch 16/20
# 948/948 [==============================] - 49s 52ms/step - loss: 0.2983 - accuracy: 0.8974 - val_loss: 0.3040 - val_accuracy: 0.8962
# Epoch 17/20
# 948/948 [==============================] - 48s 50ms/step - loss: 0.2980 - accuracy: 0.8976 - val_loss: 0.3025 - val_accuracy: 0.8962
# Epoch 18/20
# 948/948 [==============================] - 48s 50ms/step - loss: 0.2983 - accuracy: 0.8978 - val_loss: 0.3022 - val_accuracy: 0.8958
# Epoch 19/20
# 948/948 [==============================] - 48s 51ms/step - loss: 0.2984 - accuracy: 0.8976 - val_loss: 0.3023 - val_accuracy: 0.8962
# Epoch 20/20
# 948/948 [==============================] - 48s 51ms/step - loss: 0.2981 - accuracy: 0.8975 - val_loss: 0.3023 - val_accuracy: 0.8970

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 264/264 [==============================] - 3s 12ms/step - loss: 0.2987 - accuracy: 0.8982
# Test loss: 0.29867470264434814, Test accuracy: 0.898242712020874

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 264/264 [==============================] - 4s 12ms/step
# Accuracy: 0.8982426976965091

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1328
# True Negatives: 6237
# False Positives: 126
# False Negatives: 731

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7560489610019926
# Precision: 0.9133425034387895
# Recall: 0.6449732880038854

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

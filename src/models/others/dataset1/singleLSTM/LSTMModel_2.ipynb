# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (70646, 128, 27)

# %%
Y.shape
# Out:
# (70646,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (63581, 128, 27)
# (63581,)
# (7065, 128, 27)
# (7065,)

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(X.shape[1], X.shape[2])))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 795/795 [==============================] - 43s 50ms/step - loss: 0.3495 - accuracy: 0.8729 - val_loss: 0.3412 - val_accuracy: 0.8845
# Epoch 2/20
# 795/795 [==============================] - 30s 38ms/step - loss: 0.3252 - accuracy: 0.8852 - val_loss: 0.3244 - val_accuracy: 0.8845
# Epoch 3/20
# 795/795 [==============================] - 30s 37ms/step - loss: 0.3209 - accuracy: 0.8853 - val_loss: 0.3202 - val_accuracy: 0.8861
# Epoch 4/20
# 795/795 [==============================] - 30s 37ms/step - loss: 0.3204 - accuracy: 0.8857 - val_loss: 0.3230 - val_accuracy: 0.8856
# Epoch 5/20
# 795/795 [==============================] - 29s 37ms/step - loss: 0.3227 - accuracy: 0.8843 - val_loss: 0.3281 - val_accuracy: 0.8845
# Epoch 6/20
# 795/795 [==============================] - 32s 40ms/step - loss: 0.3211 - accuracy: 0.8854 - val_loss: 0.3212 - val_accuracy: 0.8862
# Epoch 7/20
# 795/795 [==============================] - 29s 37ms/step - loss: 0.3200 - accuracy: 0.8860 - val_loss: 0.3196 - val_accuracy: 0.8871
# Epoch 8/20
# 795/795 [==============================] - 30s 38ms/step - loss: 0.3178 - accuracy: 0.8866 - val_loss: 0.3172 - val_accuracy: 0.8868
# Epoch 9/20
# 795/795 [==============================] - 31s 38ms/step - loss: 0.3167 - accuracy: 0.8865 - val_loss: 0.3178 - val_accuracy: 0.8862
# Epoch 10/20
# 795/795 [==============================] - 30s 38ms/step - loss: 0.3164 - accuracy: 0.8868 - val_loss: 0.3162 - val_accuracy: 0.8876
# Epoch 11/20
# 795/795 [==============================] - 59s 75ms/step - loss: 0.3150 - accuracy: 0.8868 - val_loss: 0.3166 - val_accuracy: 0.8868
# Epoch 12/20
# 795/795 [==============================] - 73s 92ms/step - loss: 0.3148 - accuracy: 0.8864 - val_loss: 0.3140 - val_accuracy: 0.8868
# Epoch 13/20
# 795/795 [==============================] - 75s 94ms/step - loss: 0.3141 - accuracy: 0.8870 - val_loss: 0.3148 - val_accuracy: 0.8861
# Epoch 14/20
# 795/795 [==============================] - 73s 92ms/step - loss: 0.3136 - accuracy: 0.8867 - val_loss: 0.3131 - val_accuracy: 0.8862
# Epoch 15/20
# 795/795 [==============================] - 66s 83ms/step - loss: 0.3130 - accuracy: 0.8869 - val_loss: 0.3124 - val_accuracy: 0.8878
# Epoch 16/20
# 795/795 [==============================] - 65s 82ms/step - loss: 0.3130 - accuracy: 0.8871 - val_loss: 0.3128 - val_accuracy: 0.8861
# Epoch 17/20
# 795/795 [==============================] - 74s 93ms/step - loss: 0.3121 - accuracy: 0.8873 - val_loss: 0.3118 - val_accuracy: 0.8876
# Epoch 18/20
# 795/795 [==============================] - 75s 94ms/step - loss: 0.3124 - accuracy: 0.8871 - val_loss: 0.3169 - val_accuracy: 0.8868
# Epoch 19/20
# 795/795 [==============================] - 75s 94ms/step - loss: 0.3120 - accuracy: 0.8874 - val_loss: 0.3119 - val_accuracy: 0.8868
# Epoch 20/20
# 795/795 [==============================] - 73s 92ms/step - loss: 0.3112 - accuracy: 0.8875 - val_loss: 0.3111 - val_accuracy: 0.8876

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 221/221 [==============================] - 4s 18ms/step - loss: 0.3123 - accuracy: 0.8872
# Test loss: 0.312345415353775, Test accuracy: 0.8871904015541077

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 221/221 [==============================] - 4s 18ms/step
# Accuracy: 0.8871903750884642

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1216
# True Negatives: 5052
# False Positives: 90
# False Negatives: 707

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7531743573861877
# Precision: 0.9310872894333844
# Recall: 0.6323452938117524

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

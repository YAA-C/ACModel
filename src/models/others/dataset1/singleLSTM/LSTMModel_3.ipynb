# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (70646, 128, 27)

# %%
Y.shape
# Out:
# (70646,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (63581, 128, 27)
# (63581,)
# (7065, 128, 27)
# (7065,)

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(X.shape[1], X.shape[2])))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 795/795 [==============================] - 126s 155ms/step - loss: 0.3446 - accuracy: 0.8732 - val_loss: 0.3283 - val_accuracy: 0.8836
# Epoch 2/20
# 795/795 [==============================] - 127s 160ms/step - loss: 0.3235 - accuracy: 0.8856 - val_loss: 0.3283 - val_accuracy: 0.8857
# Epoch 3/20
# 795/795 [==============================] - 106s 133ms/step - loss: 0.3201 - accuracy: 0.8856 - val_loss: 0.3207 - val_accuracy: 0.8825
# Epoch 4/20
# 795/795 [==============================] - 134s 169ms/step - loss: 0.3201 - accuracy: 0.8855 - val_loss: 0.3228 - val_accuracy: 0.8824
# Epoch 5/20
# 795/795 [==============================] - 120s 151ms/step - loss: 0.3209 - accuracy: 0.8853 - val_loss: 0.3209 - val_accuracy: 0.8819
# Epoch 6/20
# 795/795 [==============================] - 117s 147ms/step - loss: 0.3171 - accuracy: 0.8862 - val_loss: 0.3152 - val_accuracy: 0.8862
# Epoch 7/20
# 795/795 [==============================] - 135s 169ms/step - loss: 0.3154 - accuracy: 0.8867 - val_loss: 0.3130 - val_accuracy: 0.8869
# Epoch 8/20
# 795/795 [==============================] - 135s 170ms/step - loss: 0.3147 - accuracy: 0.8869 - val_loss: 0.3129 - val_accuracy: 0.8868
# Epoch 9/20
# 795/795 [==============================] - 136s 171ms/step - loss: 0.3150 - accuracy: 0.8866 - val_loss: 0.3203 - val_accuracy: 0.8856
# Epoch 10/20
# 795/795 [==============================] - 135s 169ms/step - loss: 0.3146 - accuracy: 0.8869 - val_loss: 0.3165 - val_accuracy: 0.8861
# Epoch 11/20
# 795/795 [==============================] - 132s 166ms/step - loss: 0.3130 - accuracy: 0.8867 - val_loss: 0.3132 - val_accuracy: 0.8861
# Epoch 12/20
# 795/795 [==============================] - 133s 167ms/step - loss: 0.3135 - accuracy: 0.8872 - val_loss: 0.3145 - val_accuracy: 0.8861
# Epoch 13/20
# 795/795 [==============================] - 132s 166ms/step - loss: 0.3122 - accuracy: 0.8869 - val_loss: 0.3103 - val_accuracy: 0.8871
# Epoch 14/20
# 795/795 [==============================] - 123s 155ms/step - loss: 0.3118 - accuracy: 0.8872 - val_loss: 0.3157 - val_accuracy: 0.8867
# Epoch 15/20
# 795/795 [==============================] - 119s 150ms/step - loss: 0.3124 - accuracy: 0.8868 - val_loss: 0.3102 - val_accuracy: 0.8871
# Epoch 16/20
# 795/795 [==============================] - 118s 149ms/step - loss: 0.3127 - accuracy: 0.8870 - val_loss: 0.3153 - val_accuracy: 0.8876
# Epoch 17/20
# 795/795 [==============================] - 117s 147ms/step - loss: 0.3119 - accuracy: 0.8873 - val_loss: 0.3106 - val_accuracy: 0.8876
# Epoch 18/20
# 795/795 [==============================] - 118s 149ms/step - loss: 0.3118 - accuracy: 0.8874 - val_loss: 0.3094 - val_accuracy: 0.8876
# Epoch 19/20
# 795/795 [==============================] - 116s 146ms/step - loss: 0.3114 - accuracy: 0.8872 - val_loss: 0.3094 - val_accuracy: 0.8869
# Epoch 20/20
# 795/795 [==============================] - 117s 147ms/step - loss: 0.3113 - accuracy: 0.8876 - val_loss: 0.3115 - val_accuracy: 0.8883

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 221/221 [==============================] - 7s 33ms/step - loss: 0.3123 - accuracy: 0.8870
# Test loss: 0.3123093247413635, Test accuracy: 0.8870488405227661

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 221/221 [==============================] - 8s 34ms/step
# Accuracy: 0.8870488322717622

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1222
# True Negatives: 5045
# False Positives: 97
# False Negatives: 701

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7538556446637877
# Precision: 0.9264594389689158
# Recall: 0.6354654186167447

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

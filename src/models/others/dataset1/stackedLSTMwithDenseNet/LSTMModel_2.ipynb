# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (70646, 128, 27)

# %%
Y.shape
# Out:
# (70646,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (63581, 128, 27)
# (63581,)
# (7065, 128, 27)
# (7065,)

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(1/10))
model.add(LSTM(64))
model.add(Dropout(1/10))
model.add(Dense(X.shape[1], activation='relu'))
model.add(Dropout(1/10))
model.add(Dense(X.shape[1] / 2, activation='relu'))
model.add(Dropout(1/10))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\dhing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 795/795 [==============================] - 112s 134ms/step - loss: 0.3461 - accuracy: 0.8760 - val_loss: 0.3301 - val_accuracy: 0.8836
# Epoch 2/20
# 795/795 [==============================] - 104s 131ms/step - loss: 0.3277 - accuracy: 0.8850 - val_loss: 0.3231 - val_accuracy: 0.8865
# Epoch 3/20
# 795/795 [==============================] - 109s 137ms/step - loss: 0.3244 - accuracy: 0.8859 - val_loss: 0.3241 - val_accuracy: 0.8837
# Epoch 4/20
# 795/795 [==============================] - 107s 135ms/step - loss: 0.3218 - accuracy: 0.8862 - val_loss: 0.3197 - val_accuracy: 0.8868
# Epoch 5/20
# 795/795 [==============================] - 109s 137ms/step - loss: 0.3192 - accuracy: 0.8862 - val_loss: 0.3185 - val_accuracy: 0.8831
# Epoch 6/20
# 795/795 [==============================] - 108s 136ms/step - loss: 0.3179 - accuracy: 0.8867 - val_loss: 0.3275 - val_accuracy: 0.8862
# Epoch 7/20
# 795/795 [==============================] - 105s 133ms/step - loss: 0.3175 - accuracy: 0.8867 - val_loss: 0.3164 - val_accuracy: 0.8861
# Epoch 8/20
# 795/795 [==============================] - 107s 135ms/step - loss: 0.3156 - accuracy: 0.8872 - val_loss: 0.3130 - val_accuracy: 0.8876
# Epoch 9/20
# 795/795 [==============================] - 106s 133ms/step - loss: 0.3155 - accuracy: 0.8870 - val_loss: 0.3185 - val_accuracy: 0.8883
# Epoch 10/20
# 795/795 [==============================] - 107s 135ms/step - loss: 0.3149 - accuracy: 0.8871 - val_loss: 0.3113 - val_accuracy: 0.8885
# Epoch 11/20
# 795/795 [==============================] - 107s 135ms/step - loss: 0.3149 - accuracy: 0.8875 - val_loss: 0.3109 - val_accuracy: 0.8876
# Epoch 12/20
# 795/795 [==============================] - 106s 134ms/step - loss: 0.3160 - accuracy: 0.8870 - val_loss: 0.3125 - val_accuracy: 0.8876
# Epoch 13/20
# 795/795 [==============================] - 107s 134ms/step - loss: 0.3137 - accuracy: 0.8872 - val_loss: 0.3104 - val_accuracy: 0.8871
# Epoch 14/20
# 795/795 [==============================] - 107s 135ms/step - loss: 0.3142 - accuracy: 0.8875 - val_loss: 0.3115 - val_accuracy: 0.8876
# Epoch 15/20
# 795/795 [==============================] - 103s 130ms/step - loss: 0.3137 - accuracy: 0.8870 - val_loss: 0.3116 - val_accuracy: 0.8878
# Epoch 16/20
# 795/795 [==============================] - 103s 130ms/step - loss: 0.3135 - accuracy: 0.8872 - val_loss: 0.3154 - val_accuracy: 0.8876
# Epoch 17/20
# 795/795 [==============================] - 105s 132ms/step - loss: 0.3134 - accuracy: 0.8872 - val_loss: 0.3090 - val_accuracy: 0.8878
# Epoch 18/20
# 795/795 [==============================] - 115s 144ms/step - loss: 0.3136 - accuracy: 0.8871 - val_loss: 0.3107 - val_accuracy: 0.8876
# Epoch 19/20
# 795/795 [==============================] - 125s 157ms/step - loss: 0.3121 - accuracy: 0.8875 - val_loss: 0.3107 - val_accuracy: 0.8878
# Epoch 20/20
# 795/795 [==============================] - 126s 158ms/step - loss: 0.3128 - accuracy: 0.8873 - val_loss: 0.3115 - val_accuracy: 0.8883

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 221/221 [==============================] - 9s 41ms/step - loss: 0.3154 - accuracy: 0.8885
# Test loss: 0.3153584897518158, Test accuracy: 0.8884642720222473

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 221/221 [==============================] - 10s 39ms/step
# Accuracy: 0.8884642604387827

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1207
# True Negatives: 5070
# False Positives: 72
# False Negatives: 716

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7539038101186758
# Precision: 0.9437060203283816
# Recall: 0.6276651066042642

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

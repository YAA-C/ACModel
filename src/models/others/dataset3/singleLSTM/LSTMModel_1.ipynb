# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
assert(len(tf.config.list_physical_devices('GPU')) > 0), "You are not using GPU"
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (88202, 64, 27)

# %%
Y.shape
# Out:
# (88202,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (79381, 64, 27)
# (79381,)
# (8821, 64, 27)
# (8821,)

# %%
model = Sequential()
model.add(LSTM(32, input_shape=(X.shape[1], X.shape[2])))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# 993/993 [==============================] - 19s 16ms/step - loss: 0.3430 - accuracy: 0.8842 - val_loss: 0.3359 - val_accuracy: 0.8891
# Epoch 2/20
# 993/993 [==============================] - 14s 15ms/step - loss: 0.3176 - accuracy: 0.8933 - val_loss: 0.3234 - val_accuracy: 0.8902
# Epoch 3/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3155 - accuracy: 0.8932 - val_loss: 0.3217 - val_accuracy: 0.8902
# Epoch 4/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3144 - accuracy: 0.8934 - val_loss: 0.3231 - val_accuracy: 0.8911
# Epoch 5/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3134 - accuracy: 0.8942 - val_loss: 0.3227 - val_accuracy: 0.8914
# Epoch 6/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3130 - accuracy: 0.8943 - val_loss: 0.3214 - val_accuracy: 0.8920
# Epoch 7/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3127 - accuracy: 0.8948 - val_loss: 0.3227 - val_accuracy: 0.8909
# Epoch 8/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3138 - accuracy: 0.8941 - val_loss: 0.3222 - val_accuracy: 0.8902
# Epoch 9/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3128 - accuracy: 0.8933 - val_loss: 0.3206 - val_accuracy: 0.8903
# Epoch 10/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3122 - accuracy: 0.8944 - val_loss: 0.3203 - val_accuracy: 0.8913
# Epoch 11/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3117 - accuracy: 0.8944 - val_loss: 0.3192 - val_accuracy: 0.8913
# Epoch 12/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3114 - accuracy: 0.8945 - val_loss: 0.3198 - val_accuracy: 0.8913
# Epoch 13/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3116 - accuracy: 0.8946 - val_loss: 0.3196 - val_accuracy: 0.8913
# Epoch 14/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3113 - accuracy: 0.8947 - val_loss: 0.3202 - val_accuracy: 0.8911
# Epoch 15/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3112 - accuracy: 0.8946 - val_loss: 0.3209 - val_accuracy: 0.8904
# Epoch 16/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3108 - accuracy: 0.8948 - val_loss: 0.3201 - val_accuracy: 0.8913
# Epoch 17/20
# 993/993 [==============================] - 17s 17ms/step - loss: 0.3109 - accuracy: 0.8946 - val_loss: 0.3196 - val_accuracy: 0.8910
# Epoch 18/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3108 - accuracy: 0.8950 - val_loss: 0.3194 - val_accuracy: 0.8913
# Epoch 19/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3106 - accuracy: 0.8948 - val_loss: 0.3191 - val_accuracy: 0.8910
# Epoch 20/20
# 993/993 [==============================] - 15s 15ms/step - loss: 0.3106 - accuracy: 0.8948 - val_loss: 0.3199 - val_accuracy: 0.8913

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 276/276 [==============================] - 2s 7ms/step - loss: 0.3064 - accuracy: 0.8962
# Test loss: 0.30639708042144775, Test accuracy: 0.896156907081604

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 276/276 [==============================] - 2s 5ms/step
# Accuracy: 0.8961568983108491

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1441
# True Negatives: 6464
# False Positives: 177
# False Negatives: 739

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7588204318062138
# Precision: 0.8906056860321384
# Recall: 0.6610091743119266

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
assert(len(tf.config.list_physical_devices('GPU')) > 0), "You are not using GPU"
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (88202, 64, 27)

# %%
Y.shape
# Out:
# (88202,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (79381, 64, 27)
# (79381,)
# (8821, 64, 27)
# (8821,)

# %%
model = Sequential()
model.add(LSTM(128 , input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(1/10))
model.add(LSTM(128))
model.add(Dropout(1/10))
model.add(Dense(X.shape[1], activation='relu'))
model.add(Dropout(1/10))
model.add(Dense(X.shape[1] / 2, activation='relu'))
model.add(Dropout(1/10))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# 993/993 [==============================] - 45s 39ms/step - loss: 0.3309 - accuracy: 0.8909 - val_loss: 0.3289 - val_accuracy: 0.8902
# Epoch 2/20
# 993/993 [==============================] - 37s 37ms/step - loss: 0.3224 - accuracy: 0.8927 - val_loss: 0.3235 - val_accuracy: 0.8907
# Epoch 3/20
# 993/993 [==============================] - 39s 39ms/step - loss: 0.3190 - accuracy: 0.8941 - val_loss: 0.3214 - val_accuracy: 0.8931
# Epoch 4/20
# 993/993 [==============================] - 40s 41ms/step - loss: 0.3190 - accuracy: 0.8938 - val_loss: 0.3234 - val_accuracy: 0.8911
# Epoch 5/20
# 993/993 [==============================] - 43s 43ms/step - loss: 0.3162 - accuracy: 0.8945 - val_loss: 0.3342 - val_accuracy: 0.8914
# Epoch 6/20
# 993/993 [==============================] - 41s 42ms/step - loss: 0.3150 - accuracy: 0.8952 - val_loss: 0.3213 - val_accuracy: 0.8911
# Epoch 7/20
# 993/993 [==============================] - 41s 41ms/step - loss: 0.3145 - accuracy: 0.8951 - val_loss: 0.3269 - val_accuracy: 0.8907
# Epoch 8/20
# 993/993 [==============================] - 42s 43ms/step - loss: 0.3145 - accuracy: 0.8951 - val_loss: 0.3188 - val_accuracy: 0.8933
# Epoch 9/20
# 993/993 [==============================] - 39s 39ms/step - loss: 0.3137 - accuracy: 0.8954 - val_loss: 0.3213 - val_accuracy: 0.8907
# Epoch 10/20
# 993/993 [==============================] - 41s 42ms/step - loss: 0.3159 - accuracy: 0.8941 - val_loss: 0.3210 - val_accuracy: 0.8927
# Epoch 11/20
# 993/993 [==============================] - 41s 42ms/step - loss: 0.3136 - accuracy: 0.8952 - val_loss: 0.3260 - val_accuracy: 0.8895
# Epoch 12/20
# 993/993 [==============================] - 40s 40ms/step - loss: 0.3149 - accuracy: 0.8944 - val_loss: 0.3213 - val_accuracy: 0.8920
# Epoch 13/20
# 993/993 [==============================] - 40s 40ms/step - loss: 0.3130 - accuracy: 0.8955 - val_loss: 0.3192 - val_accuracy: 0.8933
# Epoch 14/20
# 993/993 [==============================] - 43s 43ms/step - loss: 0.3123 - accuracy: 0.8956 - val_loss: 0.3255 - val_accuracy: 0.8927
# Epoch 15/20
# 993/993 [==============================] - 44s 44ms/step - loss: 0.3136 - accuracy: 0.8948 - val_loss: 0.3229 - val_accuracy: 0.8920
# Epoch 16/20
# 993/993 [==============================] - 44s 44ms/step - loss: 0.3126 - accuracy: 0.8954 - val_loss: 0.3185 - val_accuracy: 0.8933
# Epoch 17/20
# 993/993 [==============================] - 39s 40ms/step - loss: 0.3126 - accuracy: 0.8951 - val_loss: 0.3202 - val_accuracy: 0.8919
# Epoch 18/20
# 993/993 [==============================] - 35s 35ms/step - loss: 0.3117 - accuracy: 0.8959 - val_loss: 0.3200 - val_accuracy: 0.8933
# Epoch 19/20
# 993/993 [==============================] - 38s 38ms/step - loss: 0.3112 - accuracy: 0.8956 - val_loss: 0.3203 - val_accuracy: 0.8933
# Epoch 20/20
# 993/993 [==============================] - 35s 36ms/step - loss: 0.3130 - accuracy: 0.8955 - val_loss: 0.3189 - val_accuracy: 0.8933

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 276/276 [==============================] - 2s 7ms/step - loss: 0.3059 - accuracy: 0.8963
# Test loss: 0.3058874309062958, Test accuracy: 0.8962702751159668

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 276/276 [==============================] - 2s 5ms/step
# Accuracy: 0.8962702641423875

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1441
# True Negatives: 6465
# False Positives: 176
# False Negatives: 739

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.759020279167764
# Precision: 0.891156462585034
# Recall: 0.6610091743119266

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

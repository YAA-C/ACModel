# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
assert(len(tf.config.list_physical_devices('GPU')) > 0), "You are not using GPU"
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (88202, 64, 27)

# %%
Y.shape
# Out:
# (88202,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (79381, 64, 27)
# (79381,)
# (8821, 64, 27)
# (8821,)

# %%
model = Sequential()
model.add(LSTM(32, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(1/10))
model.add(LSTM(32))
model.add(Dropout(1/10))
model.add(Dense(X.shape[1], activation='relu'))
model.add(Dropout(1/10))
model.add(Dense(X.shape[1] / 2, activation='relu'))
model.add(Dropout(1/10))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# 993/993 [==============================] - 30s 24ms/step - loss: 0.3390 - accuracy: 0.8865 - val_loss: 0.3289 - val_accuracy: 0.8902
# Epoch 2/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3238 - accuracy: 0.8929 - val_loss: 0.3264 - val_accuracy: 0.8891
# Epoch 3/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3210 - accuracy: 0.8931 - val_loss: 0.3271 - val_accuracy: 0.8907
# Epoch 4/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3184 - accuracy: 0.8940 - val_loss: 0.3221 - val_accuracy: 0.8922
# Epoch 5/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3166 - accuracy: 0.8951 - val_loss: 0.3210 - val_accuracy: 0.8931
# Epoch 6/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3154 - accuracy: 0.8949 - val_loss: 0.3205 - val_accuracy: 0.8931
# Epoch 7/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3152 - accuracy: 0.8951 - val_loss: 0.3202 - val_accuracy: 0.8931
# Epoch 8/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3144 - accuracy: 0.8952 - val_loss: 0.3212 - val_accuracy: 0.8920
# Epoch 9/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3145 - accuracy: 0.8957 - val_loss: 0.3232 - val_accuracy: 0.8920
# Epoch 10/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3152 - accuracy: 0.8945 - val_loss: 0.3196 - val_accuracy: 0.8931
# Epoch 11/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3136 - accuracy: 0.8949 - val_loss: 0.3192 - val_accuracy: 0.8933
# Epoch 12/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3122 - accuracy: 0.8955 - val_loss: 0.3188 - val_accuracy: 0.8933
# Epoch 13/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3133 - accuracy: 0.8950 - val_loss: 0.3188 - val_accuracy: 0.8931
# Epoch 14/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3127 - accuracy: 0.8957 - val_loss: 0.3200 - val_accuracy: 0.8931
# Epoch 15/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3125 - accuracy: 0.8958 - val_loss: 0.3191 - val_accuracy: 0.8927
# Epoch 16/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3127 - accuracy: 0.8953 - val_loss: 0.3186 - val_accuracy: 0.8933
# Epoch 17/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3125 - accuracy: 0.8958 - val_loss: 0.3234 - val_accuracy: 0.8933
# Epoch 18/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3133 - accuracy: 0.8954 - val_loss: 0.3199 - val_accuracy: 0.8933
# Epoch 19/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3122 - accuracy: 0.8951 - val_loss: 0.3196 - val_accuracy: 0.8933
# Epoch 20/20
# 993/993 [==============================] - 24s 24ms/step - loss: 0.3128 - accuracy: 0.8952 - val_loss: 0.3192 - val_accuracy: 0.8922

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 276/276 [==============================] - 3s 11ms/step - loss: 0.3077 - accuracy: 0.8943
# Test loss: 0.30770671367645264, Test accuracy: 0.8943430185317993

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 276/276 [==============================] - 3s 8ms/step
# Accuracy: 0.8943430450062351

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1400
# True Negatives: 6489
# False Positives: 152
# False Negatives: 780

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7502679528403001
# Precision: 0.9020618556701031
# Recall: 0.6422018348623854

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

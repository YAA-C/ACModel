# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
assert(len(tf.config.list_physical_devices('GPU')) > 0), "You are not using GPU"
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (88202, 64, 27)

# %%
Y.shape
# Out:
# (88202,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (79381, 64, 27)
# (79381,)
# (8821, 64, 27)
# (8821,)

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(1/10))
model.add(LSTM(64))
model.add(Dropout(1/10))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# 993/993 [==============================] - 35s 29ms/step - loss: 0.3287 - accuracy: 0.8906 - val_loss: 0.3261 - val_accuracy: 0.8895
# Epoch 2/20
# 993/993 [==============================] - 28s 28ms/step - loss: 0.3177 - accuracy: 0.8929 - val_loss: 0.3223 - val_accuracy: 0.8911
# Epoch 3/20
# 993/993 [==============================] - 28s 28ms/step - loss: 0.3152 - accuracy: 0.8946 - val_loss: 0.3218 - val_accuracy: 0.8907
# Epoch 4/20
# 993/993 [==============================] - 29s 29ms/step - loss: 0.3139 - accuracy: 0.8944 - val_loss: 0.3203 - val_accuracy: 0.8907
# Epoch 5/20
# 993/993 [==============================] - 29s 30ms/step - loss: 0.3128 - accuracy: 0.8949 - val_loss: 0.3195 - val_accuracy: 0.8920
# Epoch 6/20
# 993/993 [==============================] - 30s 30ms/step - loss: 0.3137 - accuracy: 0.8951 - val_loss: 0.3206 - val_accuracy: 0.8920
# Epoch 7/20
# 993/993 [==============================] - 30s 30ms/step - loss: 0.3125 - accuracy: 0.8953 - val_loss: 0.3214 - val_accuracy: 0.8920
# Epoch 8/20
# 993/993 [==============================] - 29s 29ms/step - loss: 0.3124 - accuracy: 0.8953 - val_loss: 0.3190 - val_accuracy: 0.8933
# Epoch 9/20
# 993/993 [==============================] - 30s 30ms/step - loss: 0.3116 - accuracy: 0.8955 - val_loss: 0.3183 - val_accuracy: 0.8933
# Epoch 10/20
# 993/993 [==============================] - 30s 30ms/step - loss: 0.3111 - accuracy: 0.8958 - val_loss: 0.3190 - val_accuracy: 0.8919
# Epoch 11/20
# 993/993 [==============================] - 28s 29ms/step - loss: 0.3115 - accuracy: 0.8957 - val_loss: 0.3183 - val_accuracy: 0.8931
# Epoch 12/20
# 993/993 [==============================] - 29s 29ms/step - loss: 0.3113 - accuracy: 0.8954 - val_loss: 0.3181 - val_accuracy: 0.8931
# Epoch 13/20
# 993/993 [==============================] - 28s 28ms/step - loss: 0.3107 - accuracy: 0.8961 - val_loss: 0.3190 - val_accuracy: 0.8919
# Epoch 14/20
# 993/993 [==============================] - 30s 30ms/step - loss: 0.3111 - accuracy: 0.8953 - val_loss: 0.3186 - val_accuracy: 0.8931
# Epoch 15/20
# 993/993 [==============================] - 30s 30ms/step - loss: 0.3115 - accuracy: 0.8956 - val_loss: 0.3179 - val_accuracy: 0.8933
# Epoch 16/20
# 993/993 [==============================] - 29s 29ms/step - loss: 0.3105 - accuracy: 0.8960 - val_loss: 0.3200 - val_accuracy: 0.8931
# Epoch 17/20
# 993/993 [==============================] - 28s 28ms/step - loss: 0.3105 - accuracy: 0.8957 - val_loss: 0.3183 - val_accuracy: 0.8931
# Epoch 18/20
# 993/993 [==============================] - 28s 29ms/step - loss: 0.3108 - accuracy: 0.8957 - val_loss: 0.3187 - val_accuracy: 0.8931
# Epoch 19/20
# 993/993 [==============================] - 28s 28ms/step - loss: 0.3101 - accuracy: 0.8957 - val_loss: 0.3196 - val_accuracy: 0.8931
# Epoch 20/20
# 993/993 [==============================] - 30s 30ms/step - loss: 0.3103 - accuracy: 0.8961 - val_loss: 0.3184 - val_accuracy: 0.8931

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 276/276 [==============================] - 3s 12ms/step - loss: 0.3058 - accuracy: 0.8968
# Test loss: 0.30577266216278076, Test accuracy: 0.8968371152877808

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 276/276 [==============================] - 4s 11ms/step
# Accuracy: 0.8968370933000793

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1437
# True Negatives: 6474
# False Positives: 167
# False Negatives: 743

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7595137420718816
# Precision: 0.8958852867830424
# Recall: 0.6591743119266055

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())

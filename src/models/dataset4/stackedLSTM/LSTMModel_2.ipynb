# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
assert(len(tf.config.list_physical_devices('GPU')) > 0), "You are not using GPU"
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
X = np.load("../data/X.npy")
Y = np.load("../data/Y.npy")

# %%
X.shape
# Out:
# (109511, 32, 27)

# %%
Y.shape
# Out:
# (109511,)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=452)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (98559, 32, 27)
# (98559,)
# (10952, 32, 27)
# (10952,)

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(1/10))
model.add(LSTM(64))
model.add(Dropout(1/10))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(Xtrain, Ytrain, epochs=20, batch_size=64, validation_split=0.2, use_multiprocessing=True)
# Out:
# Epoch 1/20
# 1232/1232 [==============================] - 27s 18ms/step - loss: 0.3131 - accuracy: 0.9022 - val_loss: 0.3128 - val_accuracy: 0.9025
# Epoch 2/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3059 - accuracy: 0.9061 - val_loss: 0.3126 - val_accuracy: 0.9027
# Epoch 3/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3048 - accuracy: 0.9060 - val_loss: 0.3118 - val_accuracy: 0.9030
# Epoch 4/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3044 - accuracy: 0.9061 - val_loss: 0.3121 - val_accuracy: 0.9030
# Epoch 5/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3039 - accuracy: 0.9063 - val_loss: 0.3135 - val_accuracy: 0.9029
# Epoch 6/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3037 - accuracy: 0.9064 - val_loss: 0.3114 - val_accuracy: 0.9030
# Epoch 7/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3036 - accuracy: 0.9069 - val_loss: 0.3114 - val_accuracy: 0.9030
# Epoch 8/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3039 - accuracy: 0.9067 - val_loss: 0.3120 - val_accuracy: 0.9030
# Epoch 9/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3034 - accuracy: 0.9068 - val_loss: 0.3116 - val_accuracy: 0.9030
# Epoch 10/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3030 - accuracy: 0.9066 - val_loss: 0.3109 - val_accuracy: 0.9030
# Epoch 11/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3032 - accuracy: 0.9068 - val_loss: 0.3109 - val_accuracy: 0.9030
# Epoch 12/20
# 1232/1232 [==============================] - 20s 17ms/step - loss: 0.3030 - accuracy: 0.9068 - val_loss: 0.3116 - val_accuracy: 0.9030
# Epoch 13/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3030 - accuracy: 0.9068 - val_loss: 0.3111 - val_accuracy: 0.9030
# Epoch 14/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3029 - accuracy: 0.9069 - val_loss: 0.3111 - val_accuracy: 0.9030
# Epoch 15/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3032 - accuracy: 0.9069 - val_loss: 0.3117 - val_accuracy: 0.9030
# Epoch 16/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3025 - accuracy: 0.9068 - val_loss: 0.3133 - val_accuracy: 0.9030
# Epoch 17/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3034 - accuracy: 0.9069 - val_loss: 0.3114 - val_accuracy: 0.9030
# Epoch 18/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3029 - accuracy: 0.9069 - val_loss: 0.3109 - val_accuracy: 0.9031
# Epoch 19/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3025 - accuracy: 0.9069 - val_loss: 0.3114 - val_accuracy: 0.9031
# Epoch 20/20
# 1232/1232 [==============================] - 21s 17ms/step - loss: 0.3026 - accuracy: 0.9069 - val_loss: 0.3117 - val_accuracy: 0.9030

# %%
fig, axis = plt.subplots(1, 2, figsize=(19,8))

axis[0].plot(range(0, 20), history.history["accuracy"], label= "Accuracy")
axis[0].plot(range(0, 20), history.history["val_accuracy"], label= "Validation Accuracy")
axis[0].set_title("Accuracy")
axis[0].legend(loc='upper right')

axis[1].plot(range(0, 20), history.history["loss"], label= "Loss")
axis[1].plot(range(0, 20), history.history["val_loss"], label= "Validation Loss")
axis[1].set_title("Loss")
axis[1].legend(loc='upper right')

plt.title("Model Metrics")
plt.show()

# %%
loss, accuracy = model.evaluate(Xtest, Ytest)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# 343/343 [==============================] - 4s 8ms/step - loss: 0.3054 - accuracy: 0.9060
# Test loss: 0.3053933084011078, Test accuracy: 0.9059532284736633

# %%
ypred = model.predict(Xtest)
ypred = ypred.reshape(ypred.shape[0])

threshold = 0.5
ypred = (ypred > threshold).astype(bool)

accuracy = accuracy_score(Ytest, ypred)
print(f"Accuracy: {accuracy}")
# Out:
# 343/343 [==============================] - 3s 6ms/step
# Accuracy: 0.9059532505478451

# %%
cm = confusion_matrix(Ytest, ypred)
print("Confusion Matrix:")
cmd = ConfusionMatrixDisplay(cm, display_labels = [False, True])
cmd.plot()
# Out:
# Confusion Matrix:

# %%
# Calculate TP, TN, FP, FN
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# Print the results
print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 1699
# True Negatives: 8223
# False Positives: 187
# False Negatives: 843

# %%
precision = precision_score(Ytest, ypred)
recall = recall_score(Ytest, ypred)
f1 = f1_score(Ytest, ypred)

print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# F1 Score: 0.7673893405600722
# Precision: 0.9008483563096501
# Recall: 0.6683713611329661

# %%
def getModelSaveName():
    import os
    import ipynbname

    current_directory = os.getcwd()
    directory_name = os.path.basename(current_directory)
    notebook_name = ipynbname.name()

    return f"{directory_name}_{notebook_name}.keras"

# %%
# Saving the model to a file

model.save(getModelSaveName())
